# %%
 ! pip install selenium
# Out:
# Requirement already satisfied: selenium in d:\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in d:\anaconda3\lib\site-packages (from selenium) (1.25.9)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('chromedriver.exe')
url = 'https://www.youtube.com/c/%ED%94%84%EB%A1%9C%EA%B4%80%EC%A0%84%EB%9F%ACPS/videos'
driver.get(url)

# %%
import time
SCROLL_PAUSE_TIME = 0.5
# 한번 스크롤 하고 멈출 시간 설정

body = driver.find_element_by_tag_name('body')
# body태그를 선택하여 body에 넣음

while True:
    last_height = driver.execute_script('return document.documentElement.scrollHeight')
    # 현재 화면의 길이를 리턴 받아 last_height에 넣음
    for i in range(10):
        body.send_keys(Keys.END)
        # body 본문에 END키를 입력(스크롤내림)
        time.sleep(SCROLL_PAUSE_TIME)
    new_height = driver.execute_script('return document.documentElement.scrollHeight')
    if new_height == last_height:
        break;

# %%
from bs4 import BeautifulSoup

page = driver.page_source
soup = BeautifulSoup(page, 'lxml')

# %%
all_videos = soup.find_all(id='dismissable')

title_list = []
for video in all_videos:
    title = video.find(id='video-title')
    if len(title.text.strip())>0:
        title_list.append(title.text)
    # 공백을 제거하고 글자수가 0보다 크면 append    

print(title_list)
print(len(title_list))
# Out:
# ['10.24패치 천상계 밴율 TOP10', 'PS에 대한 모든 이야기', '미리보는 10.25 패치노트 - 패치 내용이 너무 많은 것 아닙니까?', '[LIVE] 무엇이든지 물어보세요', '상남자들의 매드무비', '10.24패치 PS표 티어리스트', '10.24패치 주목해야 할 아이템 10가지', '10.24패치 떡락한 챔프 TOP9', '10.24패치 떡상한 챔프 TOP8', '10.24패치 유행할 바텀 조합입니다. 트타 유미 조합', '10.24패치 완벽정리! - 또 다시 새로운 게임이 되었습니다.', '프리시즌, 챌린저 원딜분의 플레이를 모아보았습니다.', '[10.23패치] 한국 유저들이 찾아낸 빌드 10가지 - PS 빌드 연구소', '[브실골 전용] 10.23패치 PS표 티어리스트', '10.23패치 PS표 티어리스트', '10.23패치 놓쳐서는 안 될 근황', '미리보는 10.24 패치노트 - AP 아이템 대거 밸런싱', '현재 최고의 꿀챔은? 바로 이겁니다. 태불방 메자이 누누', "드디어 적용된 '그' 핫픽스", '프리시즌, 챌린저 장인들의 플레이를 모아보았습니다.', '10.23패치 떡상한 챔프 TOP10', '10.23패치 떡락한 챔프 TOP10', '??? : 일단 패치해! 그리고 나중에 고쳐!', '프리시즌, 당신이 꼭 알아야 할 TMI 20가지', '10.23패치 완벽정리! - 이 날을 위해 준비했습니다.', '11월 11일, PS의 프리시즌 대책 회의', '원딜러전용 한타 포지션 개론 - 프로들의 습관 #18', '화제의 스트리머 세기말 골드 리그, 그 결과는?', '올해 가장 꾸준히 1티어를 찍은 챔프는?', '변경점이 너무 많아 두고두고 보려고 만들었습니다.', '[브실골 전용] 10.22패치 PS표 티어리스트', '세라핀을 때려 눕히는 방법.mp4', '알고 상대합시다. 세라핀 완벽 공략 #1', '10.22패치 PS표 티어리스트', '시즌 종료 일주일을 남기고, 솔랭 TOP10 근황 체크하기', '담원은 어떻게 우승팀이 되었나', '와일드 리프트? 궁금한 게 너무 많아 라이엇 코리아 본사 직접 다녀왔습니다.', '10.22패치 떡락한 챔프 TOP8', '10.22패치 떡상한 챔프 TOP8', '부두술 시리즈 마지막편 - 쑤닝은 어떻게 강팀이 되었나', '10.22패치 완벽정리! - 2020 정규시즌 마지막 패치, 시즌 보상을 위해 모두가 활활', '당신도 영상 속 주인공일 수 있습니다.', '더 샤이 선수의 솔랭 근황.avi', '10분만에 살펴보는 담원 vs G2 리뷰', '잔나 원챔이 유럽 솔랭 1위를 찍은 방법', '[PS 챌린지] 당신의 피지컬을 측정해 줄 콤보 45가지', '미리보는 10.22 패치노트 - 카서스는 왜 살살 때려요', '2020시즌 라이엇이 바라는 원딜의 모습은?', '숨겨왔던 PS채널의 비밀', '10.21패치 PS표 티어리스트', '10.21패치 떡락한 챔프 TOP7', '10.21패치 떡상한 챔프 TOP10', '10.21패치 완벽정리! - 너프는 제대로 준비한 10.21패치, 그 내용은?', '트페 사용법 완벽정리.pnpm', '2020 롤드컵 8강 구도 완벽정리', '대회 패치의 희생자들 TOP10', 'pnpMontage', '브실골에서 사기적인 성능을 보이는 챔프 TOP10', '롤드컵 밴픽 전략의 큰 틀을 알려드리겠습니다.', '미리보는 10.21 패치노트 - 적폐챔들 대거 너-프', '10.20패치 PS표 티어리스트', 'PS채널이 선정한 편집하면서 듣기 좋은 노래 13가지', '징동의 노림 수를 알고 있던 담원', '프리시즌에 예고된 신화급 아이템 완벽정리', '10.20패치 떡상한 챔프 TOP8', '10.20패치 떡락한 챔프 TOP9', '10.20패치 완벽정리! - 또 한 번의 큰 변화를 가져올 패치, 그 내용은?', '부두술 시리즈 3편 - G2는 어떻게 강팀이 되었나', '프로스트리머 Flame의 챌 등반기', '부두술 시리즈 2편 - 징동게이밍은 어떻게 강팀이 되었나', '부두술 시리즈 1편 - TES는 어떻게 강팀이 되었나', '[브실골 전용] 10.19패치 PS표 티어리스트', '영상 하나로 끝냅니다 - 사미라 완벽공략', '미리보는 10.20 패치노트 - 10.20패치는 저승률 챔프들을 살려낼 수 있을까', '10.19패치, 놓쳐서는 안 될 근황', '그들의 Montage를 만들어 보았습니다.', '10.19패치 PS표 티어리스트', '1코어 이후 보여줄 그 강력함 - 감전 미드 그레이브즈', '10.19패치 떡상한 챔프 TOP8', '10.19패치 떡락한 챔프 TOP10', '10.19패치 완벽정리! - 롤드컵을 위한 마지막 패치, 그 내용은?', '리안드리 vs 모렐로 누가 더 좋을까? - 10.18패치 아이템에 대한 지표들', '한국 솔로랭크 TOP10을 모아보았습니다.', '너프를 먹는다 하더라도, 이건 짚고 갑시다. 루난 원딜 세나', '지역별 프로팀들의 선호픽을 정리해드립니다.', '지역별 프로팀들이 까다로워했던 챔피언 TOP10', '미리보는 10.19 패치노트 - 롤드컵을 위한 최종 패치는 과연?', '!프로선수시점', '10.18패치 PS표 티어리스트', '10.18패치 천상계에서 자주 밴 되는 챔피언 TOP10', "원챔 챌린저들을 '다시' 모아보았습니다.", '10.18패치 떡상한 챔프 TOP8', '10.18패치 떡락한 챔프 TOP10', '10.18패치 완벽정리! - 라이엇이 그리는 대회 밸런스 윤곽이 점점 잡히다.', '원딜러들이 명심해야 할 포지셔닝 관련 습관 4가지 - 프로들의 습관 #17', '[시청자와 함께 하는 매드무비] 야스오 vs 요네', 'G2를 무너뜨린 프나틱의 비밀병기, 마나무네 미드 루시안', '[브실골 전용] 10.17패치 PS표 티어리스트', '[T1 vs AF] 데이터만으로 100% 승률 예측이 불가능한 이유', '미리보는 10.18 패치노트 - 결국 수호자를 너프하는 라이엇', '[ENG SUB] 이거 보고 가세요. - The view points of LCK Summer Playoff', '챌린저 탑 유저들을 모아보았습니다.', '10.17패치 PS표 티어리스트', '10.17패치 떡상한 챔프 TOP9', '10.17패치 떡락한 챔프 TOP10', '10.17패치 완벽정리! - 최근에 소개드린 챔프들이 모두 칼질을 당했습니다.', '요네 개발자의 또 다른 작품. 여러분은 아시나요?', '프로팀들이 계속해서 릴리아를 연구하는 이유', '누가 이렐 키웠냐 ㅡㅡ', '[브실골 전용] 10.16패치 PS표 티어리스트', '다이아구간 원딜유저들을 관전하며 느꼈던 답답함 3가지 - 프로들의 습관 #16', '칸나선수 플레이 관전을 통해 알아보는 탑 루시안의 가능성', '모르면 당합니다 - 난입 탑 헤카림', '솔랭에서 최악의 승률을 보이는 챔프 TOP10', '두 개만 알고 갑시다 - 요네 완벽 공략', 'PS표 요네 매드무비', '10.16패치 PS표 티어리스트', '천상계로부터 퍼져나가는 그 빌드 - 체력차극복 수확스타트 케틀', '10.16패치 떡상한 챔프 TOP10', '10.16패치 떡락한 챔프 TOP10', '10.16패치 완벽정리! - 이렇게 많은 챔피언 밸런싱은 처음 봤습니다.', '10.15패치 놓쳐서는 안 될 근황', '내가 바로 베인이다.', '천상계에서 보기 힘든 챔프 TOP10', '곧 솔랭에 상륙할 역겨움 - 쌍단식 럭스 소나 바텀', '챌린저 원딜들을 모아보았습니다.', '심심해서 플레이해본 요네 영상', '[ENG SUB] 미리보는 10.16 패치노트 - 24개 챔피언 밸런싱? 미쳤습니까 휴먼?', '돌격넥서스 고승률 챔프 TOP10', '10.15패치 PS표 티어리스트', '영상 하나로 끝냅니다. 릴리아 완벽 공략', '10.15패치 떡상한 챔프들', '10.15패치 떡락한 챔프 TOP10', '10.15패치 완벽정리! - 슬슬 대회 메타에 변화를 주려는 라이엇', '정말 그럴까요?', '서부리그를 노리는 팀 다이나믹스의 근황', '10.14패치 최고의 챔피언 듀오 조합을 알려드리겠습니다.', '[브실골 전용] 10.14패치 PS표 티어리스트', '[스킨이벤트 ...
# 1009

# %%
video_time_list = []
for video in all_videos:
    video_time = video.find('span',{'class' : 'style-scope ytd-thumbnail-overlay-time-status-renderer'})
    video_time_list.append(video_time.text.strip())

print(video_time_list)    
print(len(video_time_list))
# Out:
# ['14:34', '19:22', '13:32', '2:35:21', '8:13', '11:57', '12:01', '12:44', '10:11', '11:04', '10:40', '10:49', '8:23', '10:14', '10:41', '8:41', '9:33', '12:11', '2:53', '9:54', '10:04', '8:25', '8:28', '10:02', '12:30', '48:01', '12:07', '8:02', '14:05', '15:02', '9:34', '13:09', '17:24', '10:50', '8:48', '19:21', '11:30', '10:03', '12:19', '11:55', '11:54', '15:03', '5:35', '10:01', '14:58', '10:20', '13:47', '10:32', '6:22', '11:37', '14:29', '13:39', '14:07', '20:07', '15:48', '13:59', '5:14', '15:16', '10:44', '12:36', '11:18', '41:56', '6:14', '14:54', '12:29', '12:36', '13:33', '11:18', '5:15', '8:56', '14:03', '10:18', '23:44', '16:18', '9:01', '8:38', '11:04', '14:50', '10:01', '10:13', '10:52', '8:43', '9:34', '10:05', '9:39', '10:59', '10:04', '8:36', '12:53', '13:05', '19:52', '10:42', '9:45', '11:52', '15:55', '8:33', '10:01', '10:09', '13:28', '9:02', '12:54', '8:15', '10:31', '10:02', '11:06', '11:16', '8:49', '12:17', '9:56', '10:31', '14:33', '8:01', '10:26', '11:29', '14:10', '8:17', '12:23', '8:07', '11:50', '9:29', '12:05', '8:54', '10:20', '10:06', '10:37', '11:15', '6:28', '11:10', '10:58', '11:59', '20:03', '12:02', '12:39', '13:09', '18:11', '6:00', '10:52', '10:56', '2:57', '10:22', '10:01', '11:26', '5:42', '15:05', '12:13', '10:52', '10:34', '10:46', '14:22', '11:24', '13:48', '16:19', '11:40', '13:46', '10:47', '13:49', '7:34', '12:36', '12:09', '10:06', '10:52', '12:59', '13:52', '13:45', '12:44', '11:04', '12:02', '20:12', '10:02', '13:49', '13:14', '5:26', '8:55', '8:10', '10:37', '7:35', '11:37', '5:38', '12:53', '13:05', '15:19', '5:41', '10:22', '14:07', '12:47', '15:42', '10:02', '10:04', '11:04', '11:26', '7:18', '12:10', '10:26', '12:57', '14:09', '10:27', '6:17', '19:18', '10:27', '12:18', '10:04', '10:21', '13:09', '13:39', '10:05', '12:02', '15:28', '8:46', '24:13', '10:33', '20:21', '10:32', '14:30', '16:09', '14:16', '11:04', '11:28', '16:25', '8:07', '19:52', '10:17', '7:46', '15:43', '13:14', '14:06', '10:07', '12:22', '11:14', '11:32', '10:09', '11:03', '10:04', '17:15', '11:46', '18:51', '12:11', '12:36', '11:02', '10:28', '12:28', '15:51', '10:26', '10:48', '16:49', '8:08', '1:41:16', '6:46', '16:56', '10:13', '11:59', '3:19', '10:05', '15:01', '11:37', '12:32', '10:21', '10:35', '18:10', '16:44', '11:39', '6:58', '12:28', '12:52', '13:39', '16:05', '14:28', '21:07', '10:37', '13:36', '1:29', '10:12', '11:15', '10:01', '17:41', '20:27', '6:29', '11:46', '10:10', '2:01', '10:07', '12:08', '10:02', '12:33', '12:37', '10:09', '10:02', '13:34', '2:59', '15:08', '12:17', '11:06', '5:27', '11:49', '10:19', '10:28', '15:52', '10:55', '10:58', '11:48', '13:01', '12:57', '10:12', '10:42', '14:22', '7:03', '10:41', '10:11', '10:51', '14:23', '11:08', '6:00', '9:09', '12:13', '10:44', '14:15', '10:02', '11:49', '10:38', '10:59', '5:40', '18:42', '10:02', '15:20', '5:55', '11:44', '12:07', '6:34', '7:09', '1:38', '11:37', '10:03', '10:25', '10:26', '13:39', '12:07', '6:12', '5:10', '1:14:05', '18:24', '11:46', '16:30', '12:38', '1:23:50', '11:48', '15:20', '6:01', '16:10', '11:40', '10:35', '10:26', '10:06', '12:50', '7:15', '5:31', '5:06', '10:02', '11:42', '10:04', '11:27', '6:11', '13:59', '10:29', '7:19', '10:53', '14:43', '12:45', '10:09', '10:45', '12:19', '1:48', '10:09', '1:14', '10:20', '10:26', '14:03', '12:04', '14:56', '7:10', '11:05', '10:18', '10:57', '8:02', '13:27', '11:18', '16:42', '10:11', '11:46', '10:53', '6:28', '11:58', '12:00', '6:34', '12:34', '10:49', '8:38', '18:37', '0:37', '15:26', '6:05', '7:07', '11:57', '10:34', '11:03', '10:19', '10:56', '13:08', '11:33', '10:55', '11:26', '10:07', '10:55', '7:39', '10:27', '16:44', '10:08', '6:27', '11:33', '10:05', '10:43', '13:24', '2:40', '10:27', '10:21', '6:43', '1:58', '11:22', '10:25', '14:26', '10:07', '11:04', '10:49', '5:39', '0:53', '10:20', '10:14', '12:02', '11:56', '11:22', '10:03', '5:54', '11:03', '11:13', '12:58', '16:52', '12:33', '3:37', '11:18', '10:13', '5:18', '10:55', '11:19', '1:43', '10:55', '7:35', '1 ...
# 1009

# %%
def stime(text):
    time = text.split(':')
    if len(time) == 1:
        return int(time[0])
    elif len(time) == 2:
        return int(time[0])*60 + int(time[1])
    else:
        return int(time[0])*3600 + int(time[1]*60 + int(time[2]))
    
video_time_seperate_list = []
for time in video_time_list:
    video_time_seperate_list.append(stime(time))

print(video_time_seperate_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2ac43e806b00> in <module>
#      10 video_time_seperate_list = []
#      11 for time in video_time_list:
# ---> 12     video_time_seperate_list.append(stime(time))
#      13
#      14 print(video_time_seperate_list)
#
# <ipython-input-6-2ac43e806b00> in stime(text)
#       6         return int(time[0])*60 + int(time[1])
#       7     else:
# ----> 8         return int(time[0])*3600 + int(time[1]*60 + int(time[2]))
#       9
#      10 video_time_seperate_list = []
#
# TypeError: can only concatenate str (not "int") to str

# %%
import re

view_num_list = []
view_num_regexp = re.compile(r'조회수')
for video in all_videos:
    view_num = video.find('span',{'class':'style-scope ytd-grid-video-renderer'})
    if view_num_regexp.search(view_num.text):
        # view_num.text 에 '조회수' 문자열이 있으면 True
        view_num_list.append(view_num.text)
view_num_list
# Out:
# ['조회수 6만회',
#  '조회수 17만회',
#  '조회수 40만회',
#  '조회수 4.2만회',
#  '조회수 44만회',
#  '조회수 21만회',
#  '조회수 21만회',
#  '조회수 24만회',
#  '조회수 36만회',
#  '조회수 24만회',
#  '조회수 31만회',
#  '조회수 15만회',
#  '조회수 38만회',
#  '조회수 10만회',
#  '조회수 21만회',
#  '조회수 27만회',
#  '조회수 21만회',
#  '조회수 11만회',
#  '조회수 30만회',
#  '조회수 14만회',
#  '조회수 41만회',
#  '조회수 29만회',
#  '조회수 40만회',
#  '조회수 38만회',
#  '조회수 29만회',
#  '조회수 11만회',
#  '조회수 25만회',
#  '조회수 10만회',
#  '조회수 18만회',
#  '조회수 24만회',
#  '조회수 11만회',
#  '조회수 23만회',
#  '조회수 17만회',
#  '조회수 23만회',
#  '조회수 21만회',
#  '조회수 32만회',
#  '조회수 6.7만회',
#  '조회수 20만회',
#  '조회수 32만회',
#  '조회수 17만회',
#  '조회수 21만회',
#  '조회수 36만회',
#  '조회수 58만회',
#  '조회수 37만회',
#  '조회수 19만회',
#  '조회수 71만회',
#  '조회수 12만회',
#  '조회수 41만회',
#  '조회수 27만회',
#  '조회수 23만회',
#  '조회수 31만회',
#  '조회수 31만회',
#  '조회수 20만회',
#  '조회수 35만회',
#  '조회수 22만회',
#  '조회수 21만회',
#  '조회수 11만회',
#  '조회수 29만회',
#  '조회수 16만회',
#  '조회수 22만회',
#  '조회수 22만회',
#  '조회수 8.5만회',
#  '조회수 29만회',
#  '조회수 36만회',
#  '조회수 29만회',
#  '조회수 20만회',
#  '조회수 24만회',
#  '조회수 6.4만회',
#  '조회수 18만회',
#  '조회수 8.3만회',
#  '조회수 15만회',
#  '조회수 20만회',
#  '조회수 33만회',
#  '조회수 18만회',
#  '조회수 29만회',
#  '조회수 17만회',
#  '조회수 27만회',
#  '조회수 43만회',
#  '조회수 24만회',
#  '조회수 24만회',
#  '조회수 21만회',
#  '조회수 31만회',
#  '조회수 18만회',
#  '조회수 38만회',
#  '조회수 9.9만회',
#  '조회수 14만회',
#  '조회수 20만회',
#  '조회수 22만회',
#  '조회수 25만회',
#  '조회수 12만회',
#  '조회수 27만회',
#  '조회수 24만회',
#  '조회수 28만회',
#  '조회수 26만회',
#  '조회수 22만회',
#  '조회수 9.4만회',
#  '조회수 46만회',
#  '조회수 19만회',
#  '조회수 16만회',
#  '조회수 19만회',
#  '조회수 17만회',
#  '조회수 15만회',
#  '조회수 22만회',
#  '조회수 23만회',
#  '조회수 22만회',
#  '조회수 20만회',
#  '조회수 14만회',
#  '조회수 19만회',
#  '조회수 14만회',
#  '조회수 23만회',
#  '조회수 43만회',
#  '조회수 13만회',
#  '조회수 33만회',
#  '조회수 19만회',
#  '조회수 31만회',
#  '조회수 17만회',
#  '조회수 28만회',
#  '조회수 28만회',
#  '조회수 26만회',
#  '조회수 21만회',
#  '조회수 25만회',
#  '조회수 20만회',
#  '조회수 25만회',
#  '조회수 14만회',
#  '조회수 43만회',
#  '조회수 23만회',
#  '조회수 24만회',
#  '조회수 23만회',
#  '조회수 14만회',
#  '조회수 23만회',
#  '조회수 49만회',
#  '조회수 30만회',
#  '조회수 34만회',
#  '조회수 28만회',
#  '조회수 19만회',
#  '조회수 4.8만회',
#  '조회수 20만회',
#  '조회수 17만회',
#  '조회수 5만회',
#  '조회수 28만회',
#  '조회수 25만회',
#  '조회수 20만회',
#  '조회수 10만회',
#  '조회수 22만회',
#  '조회수 27만회',
#  '조회수 19만회',
#  '조회수 16만회',
#  '조회수 24만회',
#  '조회수 14만회',
#  '조회수 13만회',
#  '조회수 28만회',
#  '조회수 22만회',
#  '조회수 17만회',
#  '조회수 75만회',
#  '조회수 25만회',
#  '조회수 14만회',
#  '조회수 9.7만회',
#  '조회수 24만회',
#  '조회수 30만회',
#  '조회수 20만회',
#  '조회수 18만회',
#  '조회수 20만회',
#  '조회수 21만회',
#  '조회수 22만회',
#  '조회수 12만회',
#  '조회수 10만회',
#  '조회수 14만회',
#  '조회수 84만회',
#  '조회수 21만회',
#  '조회수 16만회',
#  '조회수 27만회',
#  '조회수 4.6만회',
#  '조회수 18만회',
#  '조회수 23만회',
#  '조회수 31만회',
#  '조회수 20만회',
#  '조회수 17만회',
#  '조회수 14만회',
#  '조회수 34만회',
#  '조회수 23만회',
#  '조회수 21만회',
#  '조회수 17만회',
#  '조회수 26만회',
#  '조회수 47만회',
#  '조회수 26만회',
#  '조회수 29만회',
#  '조회수 23만회',
#  '조회수 28만회',
#  '조회수 16만회',
#  '조회수 15만회',
#  '조회수 11만회',
#  '조회수 25만회',
#  '조회수 23만회',
#  '조회수 16만회',
#  '조회수 26만회',
#  '조회수 38만회',
#  '조회수 26만회',
#  '조회수 13만회',
#  '조회수 35만회',
#  '조회수 56만회',
#  '조회수 28만회',
#  '조회수 40만회',
#  '조회수 35만회',
#  '조회수 22만회',
#  '조회수 28만회',
#  '조회수 16만회',
#  '조회수 63만회',
#  '조회수 3.8만회',
#  '조회수 15만회',
#  '조회수 35만회',
#  '조회수 15만회',
#  '조회수 29만회',
#  '조회수 35만회',
#  '조회수 21만회',
#  '조회수 24만회',
#  '조회수 22만회',
#  '조회수 19만회',
#  '조회수 26만회',
#  '조회수 13만회',
#  '조회수 65만회',
#  '조회수 11만회',
#  '조회수 11만회',
#  '조회수 55만회',
#  '조회수 28만회',
#  '조회수 26만회',
#  '조회수 19만회',
#  '조회수 29만회',
#  '조회수 29만회',
#  '조회수 39만회',
#  '조회수 40만회',
#  '조회수 33만회',
#  '조회수 16만회',
#  '조회수 21만회',
#  '조회수 29만회',
#  '조회수 55만회',
#  '조회수 9.2만회',
#  '조회수 34만회',
#  '조회수 9.6만회',
#  '조회수 22만회',
#  '조회수 26만회',
#  '조회수 40만회',
#  '조회수 33만회',
#  '조회수 33만회',
#  '조회수 29만회',
#  '조회수 27만회',
#  '조회수 66만회',
#  '조회수 15만회',
#  '조회수 74만회',
#  '조회수 11만회',
#  '조회수 25만회',
#  '조회수 15만회',
#  '조회수 26만회',
#  '조회수 34만회',
#  '조회수 85만회',
#  '조회수 30만회',
#  '조회수 29만회',
#  '조회수 20만회',
#  '조회수 25만회',
#  '조회수 29만회',
#  '조회수 30만회',
#  '조회수 43만회',
#  '조회수 38만회',
#  '조회수 36만회',
#  '조회수 31만회',
#  '조회수 23만회',
#  '조회수 49만회',
#  '조회수 6만회',
#  '조회수 11만회',
#  '조회수 21만회',
#  '조회수 7.8만회',
#  '조회수 17만회',
#  '조회수 22만회',
#  '조회수 28만회',
#  '조회수 24만회',
#  '조회수 7.8만회',
#  '조회수 8만회',
#  '조회수 21만회',
#  '조회수 37만회',
#  '조회수 7.2만회',
#  '조회수 19만회',
#  '조회수 35만회',
#  '조회수 44만회',
#  '조회수 20만회',
#  '조회수 18만회',
#  '조회수 30만회',
#  '조회수 38만회',
#  '조회수 11만회',
#  '조회수 20만회',
#  '조회수 28만회',
#  '조회수 10만회',
#  '조회수 25만회',
#  '조회수 16만회',
#  '조회수 11만회',
#  '조회수 30만회',
#  '조회수 19만회',
#  '조회수 8.9만회',
#  '조회수 30만회',
#  '조회수 18만회',
#  '조회수 18만회',
#  '조회수 19만회',
#  '조회수 26만회',
#  '조회수 38만회',
#  '조회수 25만회',
#  '조회수 26만회',
#  '조회수 5.2만회',
#  '조회수 7.3만회',
#  '조회수 10만회',
#  '조회수 19만회',
#  '조회수 20만회',
#  '조회수 43만회',
#  '조회수 9.6만회',
#  '조회수 4만회',
#  '조회수 25만회',
#  '조회수 43만회',
#  '조회수 40만회',
#  '조회수 47만회',
#  '조회수 24만회',
#  '조회수 38만회',
#  '조회수 18만회',
#  '조회수 10만회',
#  '조회수 27만회',
#  '조회수 16만회',
#  '조회수 44만회',
#  '조회수 5.1만회',
#  '조회수 20만회',
#  '조회수 44만회',
#  '조회수 34만회',
#  '조회수 5.2만회',
#  '조회수 9.4만회',
#  '조회수 14만회',
#  '조회수 23만회',
#  '조회수 26만회',
#  '조회수 29만회',
#  '조회수 28만회',
#  '조회수 24만회',
#  '조회수 15만회',
#  '조회수 11만회',
#  '조회수 33만회',
#  '조회수 38만회',
#  '조회수 11만회',
#  '조회수 73만회',
#  '조회수 23만회',
#  '조회수 204만회',
#  '조회수 26만회',
#  '조회수 4.4만회',
#  '조회수 4.3만회',
#  '조회수 6.9만회',
#  '조회수 15만회',
#  '조회수 8.3만회',
#  '조회수 27만회',
#  '조회수 26만회',
#  '조회수 28만회',
#  '조회수 4.9만회',
#  '조회수 12만회',
#  '조회수 38만회',
#  '조회수 13만회',
#  '조회수 28만회',
#  '조회수 44만회',
#  '조회수 30만회',
#  '조회수 22만회',
#  '조회수 21만회',
#  '조회수 9.3만회',
#  '조회수 6.3만회',
#  '조회수 14만회',
#  '조회수 39만회',
#  '조회수 13만회',
#  '조회수 31만회',
#  '조회수 50만회',
#  '조회수 17만회',
#  '조회수 6.6만회',
#  '조회수 7.3만회',
#  '조회수 1.5만회',
#  '조회수 20만회',
#  '조회수 30만회',
#  '조회수 10만회',
#  '조회수 30만회',
#  '조회수 28만회',
#  '조회수 14만회',
#  '조회수 27만회',
#  '조회수 4.4만회',
#  '조회수 15만회',
#  '조회수 7.7만회',
#  '조회수 10만회',
#  '조회수 13만회',
#  '조회수 21만회',
#  '조회수 12만회',
#  '조회수 14만회',
#  '조회수 23만회',
#  '조회수 21만회',
#  '조회수 36만회',
#  '조회수 37만회',
#  '조회수 14만회',
#  '조회수 29만회',
#  '조회수 49만회',
#  '조회수 26만회',
#  '조회수 14만회',
#  '조회수 9.1만회',
#  '조회수 10만회',
#  '조회수 10만회',
#  '조회수 22만회',
#  '조회수 34만회',
#  '조회수 36만회',
#  '조회수 8.6만회',
#  '조회수 13만회',
#  '조회수 12만회',
#  '조회수 19만회',
#  '조회수 32만회',
#  '조회수 9.3만회',
#  '조회수 33만회',
#  '조회수 34만회',
#  '조회수 45만회',
#  '조회수 36만회',
#  '조회수 31만회',
#  '조회수 11만회',
#  '조회수 18만회',
#  '조회수 17만회',
#  '조회수 14만회',
#  '조회수 12만회',
#  '조회수 77만회',
#  '조회수 22만회',
#  '조회수 16만회',
#  '조회수 39만회',
#  '조회수 17만회',
#  '조회수 3.7만회',
#  '조회수 45만회',
#  '조회수 26만회',
#  '조회수 26만회',
#  '조회수 10만회',
#  '조회수 33만회',
#  '조회수 10만회',
#  '조회수 5.6만회',
#  '조회수 1.7만회',
#  '조회수 3.2만회',
#  '조회수 16만회',
#  '조회수 9.4만회',
#  '조회수 26만회',
#  '조회수 5.7만회',
#  '조회수 27만회',
#  '조회수 14만회',
#  '조회수 1.8만회',
#  '조회수 5.7만회',
#  '조회수 7.6만회',
#  '조회수 5.2만회',
#  '조회수 6만회',
#  '조회수 23만회',
#  '조회수 14만회',
#  '조회수 14만회',
#  '조회수 5만회',
#  '조회수 3.9만회',
#  '조회수 9만회',
#  '조회수 9.2만회',
#  '조회수 17만회',
#  '조회수 20만회',
#  '조회수 21만회',
#  '조회수 28만회',
#  '조회수 9만회',
#  '조회수 12만회',
#  '조회수 9.7만회',
#  '조회수 3.9만회',
#  '조회수 25만회',
#  '조회수 20만회',
#  '조회수 19만회',
#  '조회수 187만회',
#  '조회수 23만회',
#  '조회수 7.2만회',
#  '조회수 57만회',
#  '조회수 2.9만회',
#  '조회수 27만회',
#  '조회수 22만회',
#  '조회수 15만회',
#  '조회수 52만회',
#  '조회수 23만회',
#  '조회수 13만회',
#  '조회수 2.7만회',
#  '조회수 8.8만회',
#  '조회수 10만회',
#  '조회수 8.8만회',
#  '조회수 25만회',
#  '조회수 16만회',
#  '조회수 28만회',
#  '조회수 12만회',
#  '조회수 3.4만회',
#  '조회수 22만회',
#  '조회수 3.9만회',
#  '조회수 11만회',
#  '조회수 7.4만회',
#  '조회수 6.3만회',
#  '조회수 24만회',
#  '조회수 12만회',
#  '조회수 4.7만회',
#  '조회수 10만회',
#  '조회수 13만회',
#  '조회수 13만회',
#  '조회수 7.8만회',
#  '조회수 23만회',
#  '조회수 3.8만회',
#  '조회수 15만회',
#  '조회수 29만회',
#  '조회수 10만회',
#  '조회수 6.8만회',
#  '조회수 33만회',
#  '조회수 11만회',
#  '조회수 17만회',
#  '조회수 39만회',
#  '조회수 3.1만회',
#  '조회수 16만회',
#  '조회수 5.8만회',
#  '조회수 6.3만회',
#  '조회수 17만회',
#  '조회수 10만회',
#  '조회수 20만회',
#  '조회수 3.5만회',
#  '조회수 32만회',
#  '조회수 2.9만회',
#  '조회수 7.6만회',
#  '조회수 9.1만회',
#  '조회수 2.9만회',
#  '조회수 20만회',
#  '조회수 14만회',
#  '조회수 96만회',
#  '조회수 14만회',
#  '조회수 3.1만회',
#  '조회수 27만회',
#  '조회수 10만회',
#  '조회수 12만회',
#  '조회수 9.2만회',
#  '조회수 6만회',
#  '조회수 9.5만회',
#  '조회수 18만회',
#  '조회수 5.8만회',
#  '조회수 3.2만회',
#  '조회수 15만회',
#  '조회수 20만회',
#  '조회수 13만회',
#  '조회수 2.9만회',
#  '조회수 11만회',
#  '조회수 13만회',
#  '조회수 3.8만회',
#  '조회수 16만회',
#  '조회수 21만회',
#  '조회수 17만회',
#  '조회수 28만회',
#  '조회수 22만회',
#  '조회수 10만회',
#  '조회수 2.7만회',
#  '조회수 8.4만회',
#  '조회수 7.6만회',
#  '조회수 20만회',
#  '조회수 4.9만회',
#  '조회수 7.9만회',
#  '조회수 15만회',
#  '조회수 12만회',
#  '조회수 11만회',
#  '조회수 2.6만회',
#  '조회수 12만회',
#  '조회수 7.9만회',
#  '조회수 30만회',
#  '조회수 16만회',
#  '조회수 17만회',
#  '조회수 26만회',
#  '조회수 29만회',
#  '조회수 2만회',
#  '조회수 12만회',
#  '조회수 2.5만회',
#  '조회수 15만회',
#  '조회수 24만회',
#  '조회수 9.6만회',
#  '조회수 9.2만회',
#  '조회수 8.7만회',
#  '조회수 22만회',
#  '조회수 10만회',
#  '조회수 10만회',
#  '조회수 3.7만회',
#  '조회수 10만회',
#  '조회수 30만회',
#  '조회수 24만회',
#  '조회수 17만회',
#  '조회수 29만회',
#  '조회수 15만회',
#  '조회수 7.3만회',
#  '조회수 31만회',
#  '조회수 8.8만회',
#  '조회수 13만회',
#  '조회수 12만회',
#  '조회수 21만회',
#  '조회수 27만회',
#  '조회수 22만회',
#  '조회수 8.5만회',
#  '조회수 3.4만회',
#  '조회수 106만회',
#  '조회수 9.7만회',
#  '조회수 7.9만회',
#  '조회수 9.7만회',
#  '조회수 14만회',
#  '조회수 4.6만회',
#  '조회수 3.6만회',
#  '조회수 1.7만회',
#  '조회수 22만회',
#  '조회수 17만회',
#  '조회수 14만회',
#  '조회수 12만회',
#  '조회수 24만회',
#  '조회수 17만회',
#  '조회수 12만회',
#  '조회수 15만회',
#  '조회수 14만회',
#  '조회수 7.9만회',
#  '조회수 17만회',
#  '조회수 18만회',
#  '조회수 8.4만회',
#  '조회수 1.7만회',
#  '조회수 18만회',
#  '조회수 29만회',
#  '조회수 18만회',
#  '조회수 29만회',
#  '조회수 53만회',
#  '조회수 30만회',
#  '조회수 25만회',
#  '조회수 11만회',
#  '조회수 17만회',
#  '조회수 27만회',
#  '조회수 13만회',
#  '조회수 6.5만회',
#  '조회수 16만회',
#  '조회수 10만회',
#  '조회수 21만회',
#  '조회수 9.5만회',
#  '조회수 22만회',
#  '조회수 30만회',
#  '조회수 15만회',
#  '조회수 21만회',
#  '조회수 24만회',
#  '조회수 14만회',
#  '조회수 61만회',
#  '조회수 8.3만회',
#  '조회수 4.3만회',
#  '조회수 12만회',
#  '조회수 7.9만회',
#  '조회수 2.2만회',
#  '조회수 4.5만회',
#  '조회수 77만회',
#  '조회수 11만회',
#  '조회수 3.2만회',
#  '조회수 14만회',
#  '조회수 16만회',
#  '조회수 2.6만회',
#  '조회수 4.8만회',
#  '조회수 47만회',
#  '조회수 4만회',
#  '조회수 8만회',
#  '조회수 3.3만회',
#  '조회수 9.1만회',
#  '조회수 6만회',
#  '조회수 11만회',
#  '조회수 2.1만회',
#  '조회수 5.8만회',
#  '조회수 1만회',
#  '조회수 4.2만회',
#  '조회수 1만회',
#  '조회수 4만회',
#  '조회수 1.8만회',
#  '조회수 2.7만회',
#  '조회수 7만회',
#  '조회수 1.4만회',
#  '조회수 5.8만회',
#  '조회수 4.8만회',
#  '조회수 15만회',
#  '조회수 12만회',
#  '조회수 12만회',
#  '조회수 8.3만회',
#  '조회수 2만회',
#  '조회수 2.2만회',
#  '조회수 5.1만회',
#  '조회수 2.2천회',
#  '조회수 19만회',
#  '조회수 4만회',
#  '조회수 3.5만회',
#  '조회수 9.8천회',
#  '조회수 3.2만회',
#  '조회수 1만회',
#  '조회수 1.4만회',
#  '조회수 10만회',
#  '조회수 4.5만회',
#  '조회수 12만회',
#  '조회수 7.8천회',
#  '조회수 3.8만회',
#  '조회수 5.6만회',
#  '조회수 2.8만회',
#  '조회수 3.3만회',
#  '조회수 12만회',
#  '조회수 4.2천회',
#  '조회수 1.1만회',
#  '조회수 3.8천회',
#  '조회수 9.9천회',
#  '조회수 3.6천회',
#  '조회수 1만회',
#  '조회수 7.6천회',
#  '조회수 8.9천회',
#  '조회수 6.4천회',
#  '조회수 3.9천회',
#  '조회수 15만회',
#  '조회수 1.2만회',
#  '조회수 1.7만회',
#  '조회수 1만회',
#  '조회수 8.7만회',
#  '조회수 15만회',
#  '조회수 29만회',
#  '조회수 20만회',
#  '조회수 7.7만회',
#  '조회수 27만회',
#  '조회수 961회',
#  '조회수 1.3만회',
#  '조회수 12만회',
#  '조회수 2.6만회',
#  '조회수 1만회',
#  '조회수 5.7만회',
#  '조회수 1.4천회',
#  '조회수 4천회',
#  '조회수 1.2만회',
#  '조회수 7.8만회',
#  '조회수 3.9천회',
#  '조회수 1.8천회',
#  '조회수 8.7천회',
#  '조회수 37만회',
#  '조회수 6.5만회',
#  '조회수 6만회',
#  '조회수 2.4만회',
#  '조회수 1.8천회',
#  '조회수 1.9만회',
#  '조회수 11만회',
#  '조회수 9.6천회',
#  '조회수 1.3만회',
#  '조회수 4.4만회',
#  '조회수 4천회',
#  '조회수 1.4천회',
#  '조회수 7.6천회',
#  '조회수 3.7천회',
#  '조회수 3.8천회',
#  '조회수 1.8천회',
#  '조회수 1.3천회',
#  '조회수 1.9천회',
#  '조회수 3천회',
#  '조회수 2.8천회',
#  '조회수 1.1만회',
#  '조회수 3.4천회',
#  '조회수 1.3만회',
#  '조회수 7.5천회',
#  '조회수 1.7만회',
#  '조회수 2.7천회',
#  '조회수 1.1천회',
#  '조회수 4천회',
#  '조회수 7.7천회',
#  '조회수 2.3천회',
#  '조회수 1.2만회',
#  '조회수 2.4천회',
#  '조회수 3.2천회',
#  '조회수 1만회',
#  '조회수 557회',
#  '조회수 8.1천회',
#  '조회수 5.1만회',
#  '조회수 1.1만회',
#  '조회수 513회',
#  '조회수 9.5천회',
#  '조회수 2.9만회',
#  '조회수 2.9천회',
#  '조회수 889회',
#  '조회수 593회',
#  '조회수 1.6천회',
#  '조회수 2.6천회',
#  '조회수 1천회',
#  '조회수 2.1천회',
#  '조회수 1.6천회',
#  '조회수 624회',
#  '조회수 5.1만회',
#  '조회수 7.7천회',
#  '조회수 8.1천회',
#  '조회수 1.9천회',
#  '조회수 8.7천회',
#  '조회수 2.1천회',
#  '조회수 3.6천회',
#  '조회수 5.4천회',
#  '조회수 8만회',
#  '조회수 398회',
#  '조회수 2.7천회',
#  '조회수 1.5천회',
#  '조회수 3.1만회',
#  '조회수 2만회',
#  '조회수 629회',
#  '조회수 1.7천회',
#  '조회수 2.6천회',
#  '조회수 6.1천회',
#  '조회수 5.6천회',
#  '조회수 1.1천회',
#  '조회수 2.5천회',
#  '조회수 1.1만회',
#  '조회수 1.7천회',
#  '조회수 3.3천회',
#  '조회수 3.1만회',
#  '조회수 9천회',
#  '조회수 1.6천회',
#  '조회수 121만회',
#  '조회수 2.3천회',
#  '조회수 733회',
#  '조회수 11만회',
#  '조회수 2.1천회',
#  '조회수 1.3천회',
#  '조회수 1.5천회',
#  '조회수 4.3천회',
#  '조회수 3.6천회',
#  '조회수 1.6만회',
#  '조회수 2.5천회',
#  '조회수 4.7천회',
#  '조회수 8.3천회',
#  '조회수 2.4만회',
#  '조회수 404회',
#  '조회수 4.1천회',
#  '조회수 817회',
#  '조회수 1천회',
#  '조회수 1.1천회',
#  '조회수 4.6만회',
#  '조회수 3.8천회',
#  '조회수 1만회',
#  '조회수 8천회',
#  '조회수 1천회',
#  '조회수 837회',
#  '조회수 9.2천회',
#  '조회수 572회',
#  '조회수 1.1천회',
#  '조회수 1천회',
#  '조회수 418회',
#  '조회수 5천회',
#  '조회수 1.5천회',
#  '조회수 6.2천회',
#  '조회수 13만회',
#  '조회수 5.9천회',
#  '조회수 752회',
#  '조회수 2.5천회',
#  '조회수 1.2천회',
#  '조회수 1.8천회',
#  '조회수 468회',
#  '조회수 720회',
#  '조회수 2.1천회',
#  '조회수 2.6천회',
#  '조회수 1.3천회',
#  '조회수 878회',
#  '조회수 38만회',
#  '조회수 1천회',
#  '조회수 5천회',
#  '조회수 1.7천회',
#  '조회수 9.6천회',
#  '조회수 1.9천회',
#  '조회수 334회',
#  '조회수 1.8천회',
#  '조회수 387회',
#  '조회수 3.9천회',
#  '조회수 7.2천회',
#  '조회수 5.5천회',
#  '조회수 2.7만회',
#  '조회수 1천회',
#  '조회수 848회',
#  '조회수 2.6천회',
#  '조회수 1.5천회',
#  '조회수 1.1천회',
#  '조회수 397회',
#  '조회수 1.3천회',
#  '조회수 1천회',
#  '조회수 1천회',
#  '조회수 1.7천회',
#  '조회수 643회',
#  '조회수 2.2천회',
#  '조회수 378회',
#  '조회수 934회',
#  '조회수 743회',
#  '조회수 6천회',
#  '조회수 3.9천회',
#  '조회수 1천회',
#  '조회수 2.6천회',
#  '조회수 2.8천회',
#  '조회수 1.4천회',
#  '조회수 1.6만회',
#  '조회수 6.7천회',
#  '조회수 6.1천회',
#  '조회수 2.1천회',
#  '조회수 720회',
#  '조회수 1.9천회',
#  '조회수 259회',
#  '조회수 1천회',
#  '조회수 2.6만회',
#  '조회수 1.6천회',
#  '조회수 343회',
#  '조회수 859회',
#  '조회수 1.8천회',
#  '조회수 710회',
#  '조회수 5.1천회',
#  '조회수 512회',
#  '조회수 1.5천회',
#  '조회수 1.6천회',
#  '조회수 1.7천회',
#  '조회수 2.1천회',
#  '조회수 1.4천회',
#  '조회수 503회',
#  '조회수 6.8천회',
#  '조회수 707회',
#  '조회수 4.2천회',
#  '조회수 1.8천회',
#  '조회수 6.7천회',
#  '조회수 1.2천회',
#  '조회수 908회',
#  '조회수 1.7천회',
#  '조회수 805회',
#  '조회수 4천회',
#  '조회수 511회',
#  '조회수 534회',
#  '조회수 340회',
#  '조회수 369회',
#  '조회수 5.7만회',
#  '조회수 893회',
#  '조회수 1.7천회',
#  '조회수 1.2천회',
#  '조회수 2천회',
#  '조회수 416회',
#  '조회수 841회',
#  '조회수 5.2천회',
#  '조회수 3.8천회',
#  '조회수 482회',
#  '조회수 1.3천회',
#  '조회수 999회',
#  '조회수 1.5천회',
#  '조회수 667회',
#  '조회수 926회',
#  '조회수 2.5천회',
#  '조회수 6천회',
#  '조회수 88회',
#  '조회수 2.4천회',
#  '조회수 278회',
#  '조회수 204회',
#  '조회수 697회',
#  '조회수 245회',
#  '조회수 215회',
#  '조회수 207회',
#  '조회수 490회',
#  '조회수 864회',
#  '조회수 2천회',
#  '조회수 226회',
#  '조회수 15만회',
#  '조회수 427회',
#  '조회수 286회',
#  '조회수 1.2천회',
#  '조회수 989회',
#  '조회수 1.5천회',
#  '조회수 384회',
#  '조회수 925회',
#  '조회수 576회',
#  '조회수 203회',
#  '조회수 175회',
#  '조회수 279회',
#  '조회수 291회',
#  '조회수 86회',
#  '조회수 581회',
#  '조회수 1.3천회',
#  '조회수 2.6천회',
#  '조회수 710회',
#  '조회수 2천회',
#  '조회수 4.6천회',
#  '조회수 186회',
#  '조회수 142회',
#  '조회수 112회',
#  '조회수 405회',
#  '조회수 485회',
#  '조회수 436회',
#  '조회수 146회',
#  '조회수 319회',
#  '조회수 172회',
#  '조회수 315회',
#  '조회수 52회',
#  '조회수 42회',
#  '조회수 6.6천회',
#  '조회수 1.4천회',
#  '조회수 1.4천회',
#  '조회수 670회',
#  '조회수 768회',
#  '조회수 1.5천회',
#  '조회수 24만회',
#  '조회수 735회',
#  '조회수 1.5천회',
#  '조회수 1.4천회',
#  '조회수 1.1천회',
#  '조회수 714회',
#  '조회수 533회',
#  '조회수 1.4천회',
#  '조회수 275회',
#  '조회수 984회',
#  '조회수 3.1만회',
#  '조회수 622회',
#  '조회수 1.6천회',
#  '조회수 662회',
#  '조회수 2.1천회',
#  '조회수 532회',
#  '조회수 1.2천회',
#  '조회수 686회',
#  ...]

# %%
def nview(text):
    view = text.replace('조회수','')
    num = float(view[:-2])
    danwee = view[-2:]
    if danwee == '만회':
        return int(num*10000)
    elif danwee == '천회':
        return int(num*1000)
    else:
        return int((num//10)*100)
        
view_number_type_list = []
for view in view_num_list:
    view_number_type_list.append(nview(view))

view_number_type_list
# Out:
# [60000,
#  170000,
#  400000,
#  42000,
#  440000,
#  210000,
#  210000,
#  240000,
#  360000,
#  240000,
#  310000,
#  150000,
#  380000,
#  100000,
#  210000,
#  270000,
#  210000,
#  110000,
#  300000,
#  140000,
#  410000,
#  290000,
#  400000,
#  380000,
#  290000,
#  110000,
#  250000,
#  100000,
#  180000,
#  240000,
#  110000,
#  230000,
#  170000,
#  230000,
#  210000,
#  320000,
#  67000,
#  200000,
#  320000,
#  170000,
#  210000,
#  360000,
#  580000,
#  370000,
#  190000,
#  710000,
#  120000,
#  410000,
#  270000,
#  230000,
#  310000,
#  310000,
#  200000,
#  350000,
#  220000,
#  210000,
#  110000,
#  290000,
#  160000,
#  220000,
#  220000,
#  85000,
#  290000,
#  360000,
#  290000,
#  200000,
#  240000,
#  64000,
#  180000,
#  83000,
#  150000,
#  200000,
#  330000,
#  180000,
#  290000,
#  170000,
#  270000,
#  430000,
#  240000,
#  240000,
#  210000,
#  310000,
#  180000,
#  380000,
#  99000,
#  140000,
#  200000,
#  220000,
#  250000,
#  120000,
#  270000,
#  240000,
#  280000,
#  260000,
#  220000,
#  94000,
#  460000,
#  190000,
#  160000,
#  190000,
#  170000,
#  150000,
#  220000,
#  230000,
#  220000,
#  200000,
#  140000,
#  190000,
#  140000,
#  230000,
#  430000,
#  130000,
#  330000,
#  190000,
#  310000,
#  170000,
#  280000,
#  280000,
#  260000,
#  210000,
#  250000,
#  200000,
#  250000,
#  140000,
#  430000,
#  230000,
#  240000,
#  230000,
#  140000,
#  230000,
#  490000,
#  300000,
#  340000,
#  280000,
#  190000,
#  48000,
#  200000,
#  170000,
#  50000,
#  280000,
#  250000,
#  200000,
#  100000,
#  220000,
#  270000,
#  190000,
#  160000,
#  240000,
#  140000,
#  130000,
#  280000,
#  220000,
#  170000,
#  750000,
#  250000,
#  140000,
#  97000,
#  240000,
#  300000,
#  200000,
#  180000,
#  200000,
#  210000,
#  220000,
#  120000,
#  100000,
#  140000,
#  840000,
#  210000,
#  160000,
#  270000,
#  46000,
#  180000,
#  230000,
#  310000,
#  200000,
#  170000,
#  140000,
#  340000,
#  230000,
#  210000,
#  170000,
#  260000,
#  470000,
#  260000,
#  290000,
#  230000,
#  280000,
#  160000,
#  150000,
#  110000,
#  250000,
#  230000,
#  160000,
#  260000,
#  380000,
#  260000,
#  130000,
#  350000,
#  560000,
#  280000,
#  400000,
#  350000,
#  220000,
#  280000,
#  160000,
#  630000,
#  38000,
#  150000,
#  350000,
#  150000,
#  290000,
#  350000,
#  210000,
#  240000,
#  220000,
#  190000,
#  260000,
#  130000,
#  650000,
#  110000,
#  110000,
#  550000,
#  280000,
#  260000,
#  190000,
#  290000,
#  290000,
#  390000,
#  400000,
#  330000,
#  160000,
#  210000,
#  290000,
#  550000,
#  92000,
#  340000,
#  96000,
#  220000,
#  260000,
#  400000,
#  330000,
#  330000,
#  290000,
#  270000,
#  660000,
#  150000,
#  740000,
#  110000,
#  250000,
#  150000,
#  260000,
#  340000,
#  850000,
#  300000,
#  290000,
#  200000,
#  250000,
#  290000,
#  300000,
#  430000,
#  380000,
#  360000,
#  310000,
#  230000,
#  490000,
#  60000,
#  110000,
#  210000,
#  78000,
#  170000,
#  220000,
#  280000,
#  240000,
#  78000,
#  80000,
#  210000,
#  370000,
#  72000,
#  190000,
#  350000,
#  440000,
#  200000,
#  180000,
#  300000,
#  380000,
#  110000,
#  200000,
#  280000,
#  100000,
#  250000,
#  160000,
#  110000,
#  300000,
#  190000,
#  89000,
#  300000,
#  180000,
#  180000,
#  190000,
#  260000,
#  380000,
#  250000,
#  260000,
#  52000,
#  73000,
#  100000,
#  190000,
#  200000,
#  430000,
#  96000,
#  40000,
#  250000,
#  430000,
#  400000,
#  470000,
#  240000,
#  380000,
#  180000,
#  100000,
#  270000,
#  160000,
#  440000,
#  51000,
#  200000,
#  440000,
#  340000,
#  52000,
#  94000,
#  140000,
#  230000,
#  260000,
#  290000,
#  280000,
#  240000,
#  150000,
#  110000,
#  330000,
#  380000,
#  110000,
#  730000,
#  230000,
#  2040000,
#  260000,
#  44000,
#  43000,
#  69000,
#  150000,
#  83000,
#  270000,
#  260000,
#  280000,
#  49000,
#  120000,
#  380000,
#  130000,
#  280000,
#  440000,
#  300000,
#  220000,
#  210000,
#  93000,
#  63000,
#  140000,
#  390000,
#  130000,
#  310000,
#  500000,
#  170000,
#  66000,
#  73000,
#  15000,
#  200000,
#  300000,
#  100000,
#  300000,
#  280000,
#  140000,
#  270000,
#  44000,
#  150000,
#  77000,
#  100000,
#  130000,
#  210000,
#  120000,
#  140000,
#  230000,
#  210000,
#  360000,
#  370000,
#  140000,
#  290000,
#  490000,
#  260000,
#  140000,
#  91000,
#  100000,
#  100000,
#  220000,
#  340000,
#  360000,
#  86000,
#  130000,
#  120000,
#  190000,
#  320000,
#  93000,
#  330000,
#  340000,
#  450000,
#  360000,
#  310000,
#  110000,
#  180000,
#  170000,
#  140000,
#  120000,
#  770000,
#  220000,
#  160000,
#  390000,
#  170000,
#  37000,
#  450000,
#  260000,
#  260000,
#  100000,
#  330000,
#  100000,
#  56000,
#  17000,
#  32000,
#  160000,
#  94000,
#  260000,
#  57000,
#  270000,
#  140000,
#  18000,
#  57000,
#  76000,
#  52000,
#  60000,
#  230000,
#  140000,
#  140000,
#  50000,
#  39000,
#  90000,
#  92000,
#  170000,
#  200000,
#  210000,
#  280000,
#  90000,
#  120000,
#  97000,
#  39000,
#  250000,
#  200000,
#  190000,
#  1870000,
#  230000,
#  72000,
#  570000,
#  29000,
#  270000,
#  220000,
#  150000,
#  520000,
#  230000,
#  130000,
#  27000,
#  88000,
#  100000,
#  88000,
#  250000,
#  160000,
#  280000,
#  120000,
#  34000,
#  220000,
#  39000,
#  110000,
#  74000,
#  63000,
#  240000,
#  120000,
#  47000,
#  100000,
#  130000,
#  130000,
#  78000,
#  230000,
#  38000,
#  150000,
#  290000,
#  100000,
#  68000,
#  330000,
#  110000,
#  170000,
#  390000,
#  31000,
#  160000,
#  58000,
#  63000,
#  170000,
#  100000,
#  200000,
#  35000,
#  320000,
#  29000,
#  76000,
#  91000,
#  29000,
#  200000,
#  140000,
#  960000,
#  140000,
#  31000,
#  270000,
#  100000,
#  120000,
#  92000,
#  60000,
#  95000,
#  180000,
#  58000,
#  32000,
#  150000,
#  200000,
#  130000,
#  29000,
#  110000,
#  130000,
#  38000,
#  160000,
#  210000,
#  170000,
#  280000,
#  220000,
#  100000,
#  27000,
#  84000,
#  76000,
#  200000,
#  49000,
#  79000,
#  150000,
#  120000,
#  110000,
#  26000,
#  120000,
#  79000,
#  300000,
#  160000,
#  170000,
#  260000,
#  290000,
#  20000,
#  120000,
#  25000,
#  150000,
#  240000,
#  96000,
#  92000,
#  87000,
#  220000,
#  100000,
#  100000,
#  37000,
#  100000,
#  300000,
#  240000,
#  170000,
#  290000,
#  150000,
#  73000,
#  310000,
#  88000,
#  130000,
#  120000,
#  210000,
#  270000,
#  220000,
#  85000,
#  34000,
#  1060000,
#  97000,
#  79000,
#  97000,
#  140000,
#  46000,
#  36000,
#  17000,
#  220000,
#  170000,
#  140000,
#  120000,
#  240000,
#  170000,
#  120000,
#  150000,
#  140000,
#  79000,
#  170000,
#  180000,
#  84000,
#  17000,
#  180000,
#  290000,
#  180000,
#  290000,
#  530000,
#  300000,
#  250000,
#  110000,
#  170000,
#  270000,
#  130000,
#  65000,
#  160000,
#  100000,
#  210000,
#  95000,
#  220000,
#  300000,
#  150000,
#  210000,
#  240000,
#  140000,
#  610000,
#  83000,
#  43000,
#  120000,
#  79000,
#  22000,
#  45000,
#  770000,
#  110000,
#  32000,
#  140000,
#  160000,
#  26000,
#  48000,
#  470000,
#  40000,
#  80000,
#  33000,
#  91000,
#  60000,
#  110000,
#  21000,
#  58000,
#  10000,
#  42000,
#  10000,
#  40000,
#  18000,
#  27000,
#  70000,
#  14000,
#  58000,
#  48000,
#  150000,
#  120000,
#  120000,
#  83000,
#  20000,
#  22000,
#  51000,
#  2200,
#  190000,
#  40000,
#  35000,
#  9800,
#  32000,
#  10000,
#  14000,
#  100000,
#  45000,
#  120000,
#  7800,
#  38000,
#  56000,
#  28000,
#  33000,
#  120000,
#  4200,
#  11000,
#  3800,
#  9900,
#  3600,
#  10000,
#  7600,
#  8900,
#  6400,
#  3900,
#  150000,
#  12000,
#  17000,
#  10000,
#  87000,
#  150000,
#  290000,
#  200000,
#  77000,
#  270000,
#  900,
#  13000,
#  120000,
#  26000,
#  10000,
#  57000,
#  1400,
#  4000,
#  12000,
#  78000,
#  3900,
#  1800,
#  8700,
#  370000,
#  65000,
#  60000,
#  24000,
#  1800,
#  19000,
#  110000,
#  9600,
#  13000,
#  44000,
#  4000,
#  1400,
#  7600,
#  3700,
#  3800,
#  1800,
#  1300,
#  1900,
#  3000,
#  2800,
#  11000,
#  3400,
#  13000,
#  7500,
#  17000,
#  2700,
#  1100,
#  4000,
#  7700,
#  2300,
#  12000,
#  2400,
#  3200,
#  10000,
#  500,
#  8100,
#  51000,
#  11000,
#  500,
#  9500,
#  29000,
#  2900,
#  800,
#  500,
#  1600,
#  2600,
#  1000,
#  2100,
#  1600,
#  600,
#  51000,
#  7700,
#  8100,
#  1900,
#  8700,
#  2100,
#  3600,
#  5400,
#  80000,
#  300,
#  2700,
#  1500,
#  31000,
#  20000,
#  600,
#  1700,
#  2600,
#  6100,
#  5600,
#  1100,
#  2500,
#  11000,
#  1700,
#  3300,
#  31000,
#  9000,
#  1600,
#  1210000,
#  2300,
#  700,
#  110000,
#  2100,
#  1300,
#  1500,
#  4300,
#  3600,
#  16000,
#  2500,
#  4700,
#  8300,
#  24000,
#  400,
#  4100,
#  800,
#  1000,
#  1100,
#  46000,
#  3800,
#  10000,
#  8000,
#  1000,
#  800,
#  9200,
#  500,
#  1100,
#  1000,
#  400,
#  5000,
#  1500,
#  6200,
#  130000,
#  5900,
#  700,
#  2500,
#  1200,
#  1800,
#  400,
#  700,
#  2100,
#  2600,
#  1300,
#  800,
#  380000,
#  1000,
#  5000,
#  1700,
#  9600,
#  1900,
#  300,
#  1800,
#  300,
#  3900,
#  7200,
#  5500,
#  27000,
#  1000,
#  800,
#  2600,
#  1500,
#  1100,
#  300,
#  1300,
#  1000,
#  1000,
#  1700,
#  600,
#  2200,
#  300,
#  900,
#  700,
#  6000,
#  3900,
#  1000,
#  2600,
#  2800,
#  1400,
#  16000,
#  6700,
#  6100,
#  2100,
#  700,
#  1900,
#  200,
#  1000,
#  26000,
#  1600,
#  300,
#  800,
#  1800,
#  700,
#  5100,
#  500,
#  1500,
#  1600,
#  1700,
#  2100,
#  1400,
#  500,
#  6800,
#  700,
#  4200,
#  1800,
#  6700,
#  1200,
#  900,
#  1700,
#  800,
#  4000,
#  500,
#  500,
#  300,
#  300,
#  57000,
#  800,
#  1700,
#  1200,
#  2000,
#  400,
#  800,
#  5200,
#  3800,
#  400,
#  1300,
#  900,
#  1500,
#  600,
#  900,
#  2500,
#  6000,
#  0,
#  2400,
#  200,
#  200,
#  600,
#  200,
#  200,
#  200,
#  400,
#  800,
#  2000,
#  200,
#  150000,
#  400,
#  200,
#  1200,
#  900,
#  1500,
#  300,
#  900,
#  500,
#  200,
#  100,
#  200,
#  200,
#  0,
#  500,
#  1300,
#  2600,
#  700,
#  2000,
#  4600,
#  100,
#  100,
#  100,
#  400,
#  400,
#  400,
#  100,
#  300,
#  100,
#  300,
#  0,
#  0,
#  6600,
#  1400,
#  1400,
#  600,
#  700,
#  1500,
#  240000,
#  700,
#  1500,
#  1400,
#  1100,
#  700,
#  500,
#  1400,
#  200,
#  900,
#  31000,
#  600,
#  1600,
#  600,
#  2100,
#  500,
#  1200,
#  600,
#  ...]

# %%
dict_youtube = {'title':title_list, 'view_num':view_number_type_list}

import pandas as pd
youtube = pd.DataFrame(dict_youtube)
youtube.head()
# Out:
#                                     title  view_num
# 0                    10.24패치 천상계 밴율 TOP10     60000
# 1                           PS에 대한 모든 이야기    170000
# 2  미리보는 10.25 패치노트 - 패치 내용이 너무 많은 것 아닙니까?    400000
# 3                      [LIVE] 무엇이든지 물어보세요     42000
# 4                              상남자들의 매드무비    440000

# %%
youtube.to_csv('프로관전러 영상 조회수02.csv',
              sep=',',)
# Out:
#   File "<ipython-input-19-60ea2471313d>", line 2
#     sep=',',)
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
# 600
