# %%
### Package & Module
from matplotlib import pyplot as plt
###  그래프에 굴림 글꼴 사용
plt.rcParams['font.family']='Gulim'

# %%
### Package & Module
import seaborn as sns

# %%
### Package & Module
! pip install easygui
import easygui
import pandas as pd
import numpy as np

# %%
### 프로관전러 영상 조회수.csv
file_1 = easygui.fileopenbox()
data_1 = pd.read_csv(file_1, encoding='cp949')
data_1.head()
# Out:
#    Unnamed: 0                                   title  view_num
# 0           0                    10.24패치 천상계 밴율 TOP10     60000
# 1           1                           PS에 대한 모든 이야기    170000
# 2           2  미리보는 10.25 패치노트 - 패치 내용이 너무 많은 것 아닙니까?    400000
# 3           3                      [LIVE] 무엇이든지 물어보세요     42000
# 4           4                              상남자들의 매드무비    440000

# %%
### 막대그래프 - 수직
tb = pd.crosstab(data_1['view_num'],'count')
tb.plot.bar()

# %%
filter data_1['title']="%패치%"
# Out:
#   File "<ipython-input-10-d04c10ed83c6>", line 1
#     filter data_1['title']="%패치%"
#            ^
# SyntaxError: invalid syntax

# %%
data_1_patch = data_1.loc[data_1['title'].str.contains('패치')]

# %%
data_1_patch.head()
# Out:
#    Unnamed: 0                                   title  view_num
# 0           0                    10.24패치 천상계 밴율 TOP10     60000
# 2           2  미리보는 10.25 패치노트 - 패치 내용이 너무 많은 것 아닙니까?    400000
# 5           5                       10.24패치 PS표 티어리스트    210000
# 6           6                 10.24패치 주목해야 할 아이템 10가지    210000
# 7           7                     10.24패치 떡락한 챔프 TOP9    240000

# %%
len(data_1_patch)
# Out:
# 293

# %%
### 막대그래프 - 수직
tb = pd.crosstab(data_1_patch['view_num'],'count')
tb.plot.bar()

# %%
data_1_patch['view_num'].max()
# Out:
# 530000

# %%
data_1_patch.sort_values(by=['view_num'], ascending=False)
# Out:
#      Unnamed: 0                                              title  view_num
# 615         615                        모르면 손해, 9.10패치 이후 달라진 원딜 메타    530000
# 367         367                                9.24패치 떡락한 챔프 TOP10    500000
# 265         265                     미리보는 10.6 패치노트 - 바뀌는게 뭐 이렇게 많아    490000
# 315         315                               10.2패치 떡상한 챔피언 TOP10    470000
# 410         410                                9.22패치 떡락한 챔프 Top10    450000
# ..          ...                                                ...       ...
# 561         561               TFT ] 7월1일 패치 - 이젠 3레벨에 3티어 유닛이 나온다?     20000
# 670         670       [9.6패치] 헤카림 Q 버프가 상당하다면서? 프로선수 플레이를 통해 체감해보자     20000
# 733         733                  리헨즈의 신박한 시도? 패치받은 오른과 세주아니를 서폿으로!      4000
# 770         770                              8.24패치도 피해간 유성 Q선마 카시      2100
# 919         919  오늘 패치끝나자마자 연승행진 솔랭 1위, knight8(부캐)의  플레이 엿보기 -...      2000
#
# [293 rows x 3 columns]

# %%
###plotly
! pip install plotly==4.8.1
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11435 sha256=777c64e3ea0f6a286742ae9974ce67e2d4b25d127c3672adbe2627afb8f03dd8
#   Stored in directory: c:\users\lhw81\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...

# %%
### Package & Module
import plotly.express as px
